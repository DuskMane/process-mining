# %%
import sys
sys.executable
# Out:
# '/home/proxpxd/anaconda3/envs/common311/bin/python'

# %%
import pandas as pd
from datetime import datetime
import json
from functools import reduce
import operator as op
import networkx as nx
from more_itertools import split_when, split_at, unique_everseen, flatten, repeatfunc, side_effect
from itertools import chain, islice
from statistics import mean
import numpy as np

# %%
df = pd.read_csv('repairExample.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7734 entries, 0 to 7733
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Case ID               7734 non-null   int64
#  1   Activity              7734 non-null   object
#  2   Resource              7734 non-null   object
#  3   Start Timestamp       7734 non-null   object
#  4   Complete Timestamp    7734 non-null   object
#  5   Variant               7734 non-null   object
#  6   Variant index         7734 non-null   int64
#  7   (case) description    7734 non-null   object
#  8   defectFixed           2508 non-null   object
#  9   defectType            1104 non-null   float64
#  10  lifecycle:transition  7734 non-null   object
#  11  numberRepairs         2508 non-null   float64
#  12  phoneType             1104 non-null   object
# dtypes: float64(2), int64(2), object(9)
# memory usage: 785.6+ KB

# %%
list(df.groupby('Case ID'))
# Out:
# [(1,
#      Case ID          Activity  Resource          Start Timestamp  \
#   0        1          Register    System  1970/01/02 13:23:00.000
#   1        1    Analyze Defect   Tester3  1970/01/02 13:23:00.000
#   2        1  Repair (Complex)  SolverC1  1970/01/02 13:31:00.000
#   3        1       Test Repair   Tester3  1970/01/02 13:49:00.000
#   4        1       Inform User    System  1970/01/02 14:10:00.000
#   5        1    Archive Repair    System  1970/01/02 14:10:00.000
#
#           Complete Timestamp    Variant  Variant index  \
#   0  1970/01/02 13:23:00.000  Variant 2              2
#   1  1970/01/02 13:30:00.000  Variant 2              2
#   2  1970/01/02 13:49:00.000  Variant 2              2
#   3  1970/01/02 13:55:00.000  Variant 2              2
#   4  1970/01/02 14:10:00.000  Variant 2              2
#   5  1970/01/02 14:10:00.000  Variant 2              2
#
#              (case) description defectFixed  defectType lifecycle:transition  \
#   0  Simulated process instance         NaN         NaN             complete
#   1  Simulated process instance         NaN         6.0             complete
#   2  Simulated process instance         NaN         NaN             complete
#   3  Simulated process instance        True         NaN             complete
#   4  Simulated process instance         NaN         NaN             complete
#   5  Simulated process instance        True         NaN             complete
#
#      numberRepairs phoneType
#   0            NaN       NaN
#   1            NaN        T2
#   2            NaN       NaN
#   3            0.0       NaN
#   4            NaN       NaN
#   5            0.0       NaN  ),
#  (2,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1452        2          Register    System  1970/01/01 21:36:00.000
#   1453        2    Analyze Defect   Tester6  1970/01/01 21:36:00.000
#   1454        2       Inform User    System  1970/01/01 21:57:00.000
#   1455        2  Repair (Complex)  SolverC3  1970/01/01 22:01:00.000
#   1456        2       Test Repair   Tester4  1970/01/01 22:47:00.000
#   1457        2    Archive Repair    System  1970/01/01 22:57:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   1452  1970/01/01 21:36:00.000  Variant 4              4
#   1453  1970/01/01 21:42:00.000  Variant 4              4
#   1454  1970/01/01 21:57:00.000  Variant 4              4
#   1455  1970/01/01 22:47:00.000  Variant 4              4
#   1456  1970/01/01 22:52:00.000  Variant 4              4
#   1457  1970/01/01 22:57:00.000  Variant 4              4
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1452  Simulated process instance         NaN         NaN             complete
#   1453  Simulated process instance         NaN         8.0             complete
#   1454  Simulated process instance         NaN         NaN             complete
#   1455  Simulated process instance         NaN         NaN             complete
#   1456  Simulated process instance        True         NaN             complete
#   1457  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1452            NaN       NaN
#   1453            NaN        T2
#   1454            NaN       NaN
#   1455            NaN       NaN
#   1456            0.0       NaN
#   1457            0.0       NaN  ),
#  (3,
#         Case ID         Activity  Resource          Start Timestamp  \
#   2232        3         Register    System  1970/01/01 14:09:00.000
#   2233        3   Analyze Defect   Tester3  1970/01/01 14:09:00.000
#   2234        3  Repair (Simple)  SolverS3  1970/01/01 14:34:00.000
#   2235        3      Inform User    System  1970/01/01 14:43:00.000
#   2236        3      Test Repair   Tester2  1970/01/01 14:46:00.000
#   2237        3   Archive Repair    System  1970/01/01 14:57:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   2232  1970/01/01 14:09:00.000  Variant 5              5
#   2233  1970/01/01 14:19:00.000  Variant 5              5
#   2234  1970/01/01 14:46:00.000  Variant 5              5
#   2235  1970/01/01 14:43:00.000  Variant 5              5
#   2236  1970/01/01 14:52:00.000  Variant 5              5
#   2237  1970/01/01 14:57:00.000  Variant 5              5
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   2232  Simulated process instance         NaN         NaN             complete
#   2233  Simulated process instance         NaN         2.0             complete
#   2234  Simulated process instance         NaN         NaN             complete
#   2235  Simulated process instance         NaN         NaN             complete
#   2236  Simulated process instance        True         NaN             complete
#   2237  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   2232            NaN       NaN
#   2233            NaN        T2
#   2234            NaN       NaN
#   2235            NaN       NaN
#   2236            1.0       NaN
#   2237            1.0       NaN  ),
#  (4,
#         Case ID         Activity  Resource          Start Timestamp  \
#   3003        4         Register    System  1970/01/02 01:46:00.000
#   3004        4   Analyze Defect   Tester6  1970/01/02 01:46:00.000
#   3005        4  Repair (Simple)  SolverS3  1970/01/02 02:21:00.000
#   3006        4      Inform User    System  1970/01/02 02:29:00.000
#   3007        4      Test Repair   Tester3  1970/01/02 02:32:00.000
#   3008        4   Archive Repair    System  1970/01/02 02:50:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   3003  1970/01/02 01:46:00.000  Variant 5              5
#   3004  1970/01/02 01:53:00.000  Variant 5              5
#   3005  1970/01/02 02:32:00.000  Variant 5              5
#   3006  1970/01/02 02:29:00.000  Variant 5              5
#   3007  1970/01/02 02:42:00.000  Variant 5              5
#   3008  1970/01/02 02:50:00.000  Variant 5              5
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   3003  Simulated process instance         NaN         NaN             complete
#   3004  Simulated process instance         NaN         1.0             complete
#   3005  Simulated process instance         NaN         NaN             complete
#   3006  Simulated process instance         NaN         NaN             complete
#   3007  Simulated process instance        True         NaN             complete
#   3008  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   3003            NaN       NaN
#   3004            NaN        T1
#   3005            NaN       NaN
#   3006            NaN       NaN
#   3007            1.0       NaN
#   3008            1.0       NaN  ),
#  (5,
#         Case ID          Activity  Resource          Start Timestamp  \
#   3819        5          Register    System  1970/01/02 03:41:00.000
#   3820        5    Analyze Defect   Tester1  1970/01/02 03:41:00.000
#   3821        5  Repair (Complex)  SolverC2  1970/01/02 03:53:00.000
#   3822        5       Test Repair   Tester4  1970/01/02 04:06:00.000
#   3823        5       Inform User    System  1970/01/02 04:23:00.000
#   3824        5    Archive Repair    System  1970/01/02 04:25:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   3819  1970/01/02 03:41:00.000  Variant 2              2
#   3820  1970/01/02 03:49:00.000  Variant 2              2
#   3821  1970/01/02 04:06:00.000  Variant 2              2
#   3822  1970/01/02 04:15:00.000  Variant 2              2
#   3823  1970/01/02 04:23:00.000  Variant 2              2
#   3824  1970/01/02 04:25:00.000  Variant 2              2
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   3819  Simulated process instance         NaN         NaN             complete
#   3820  Simulated process instance         NaN         5.0             complete
#   3821  Simulated process instance         NaN         NaN             complete
#   3822  Simulated process instance        True         NaN             complete
#   3823  Simulated process instance         NaN         NaN             complete
#   3824  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   3819            NaN       NaN
#   3820            NaN        T1
#   3821            NaN       NaN
#   3822            0.0       NaN
#   3823            NaN       NaN
#   3824            0.0       NaN  ),
#  (6,
#         Case ID          Activity  Resource          Start Timestamp  \
#   4581        6          Register    System  1970/01/02 18:25:00.000
#   4582        6    Analyze Defect   Tester2  1970/01/02 18:25:00.000
#   4583        6  Repair (Complex)  SolverC1  1970/01/02 18:57:00.000
#   4584        6       Test Repair   Tester3  1970/01/02 19:13:00.000
#   4585        6       Inform User    System  1970/01/02 19:18:00.000
#   4586        6    Archive Repair    System  1970/01/02 19:28:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   4581  1970/01/02 18:25:00.000  Variant 2              2
#   4582  1970/01/02 18:31:00.000  Variant 2              2
#   4583  1970/01/02 19:13:00.000  Variant 2              2
#   4584  1970/01/02 19:18:00.000  Variant 2              2
#   4585  1970/01/02 19:18:00.000  Variant 2              2
#   4586  1970/01/02 19:28:00.000  Variant 2              2
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   4581  Simulated process instance         NaN         NaN             complete
#   4582  Simulated process instance         NaN         5.0             complete
#   4583  Simulated process instance         NaN         NaN             complete
#   4584  Simulated process instance        True         NaN             complete
#   4585  Simulated process instance         NaN         NaN             complete
#   4586  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   4581            NaN       NaN
#   4582            NaN        T1
#   4583            NaN       NaN
#   4584            0.0       NaN
#   4585            NaN       NaN
#   4586            0.0       NaN  ),
#  (7,
#         Case ID          Activity  Resource          Start Timestamp  \
#   5370        7          Register    System  1970/01/02 18:37:00.000
#   5371        7    Analyze Defect   Tester4  1970/01/02 18:37:00.000
#   5372        7       Inform User    System  1970/01/02 19:01:00.000
#   5373        7  Repair (Complex)  SolverC2  1970/01/02 19:13:00.000
#   5374        7       Test Repair   Tester1  1970/01/02 19:32:00.000
#   5375        7    Restart Repair    System  1970/01/02 19:42:00.000
#   5376        7  Repair (Complex)  SolverC2  1970/01/02 19:42:00.000
#   5377        7       Test Repair   Tester3  1970/01/02 19:53:00.000
#   5378        7    Restart Repair    System  1970/01/02 20:13:00.000
#   5379        7  Repair (Complex)  SolverC3  1970/01/02 20:13:00.000
#   5380        7       Test Repair   Tester6  1970/01/02 21:02:00.000
#   5381        7    Archive Repair    System  1970/01/02 21:16:00.000
#
#              Complete Timestamp     Variant  Variant index  \
#   5370  1970/01/02 18:37:00.000  Variant 37             37
#   5371  1970/01/02 18:45:00.000  Variant 37             37
#   5372  1970/01/02 19:01:00.000  Variant 37             37
#   5373  1970/01/02 19:32:00.000  Variant 37             37
#   5374  1970/01/02 19:37:00.000  Variant 37             37
#   5375  1970/01/02 19:42:00.000  Variant 37             37
#   5376  1970/01/02 19:53:00.000  Variant 37             37
#   5377  1970/01/02 20:03:00.000  Variant 37             37
#   5378  1970/01/02 20:13:00.000  Variant 37             37
#   5379  1970/01/02 21:02:00.000  Variant 37             37
#   5380  1970/01/02 21:07:00.000  Variant 37             37
#   5381  1970/01/02 21:16:00.000  Variant 37             37
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   5370  Simulated process instance         NaN         NaN             complete
#   5371  Simulated process instance         NaN        10.0             complete
#   5372  Simulated process instance         NaN         NaN             complete
#   5373  Simulated process instance         NaN         NaN             complete
#   5374  Simulated process instance       False         NaN             complete
#   5375  Simulated process instance         NaN         NaN             complete
#   5376  Simulated process instance         NaN         NaN             complete
#   5377  Simulated process instance       False         NaN             complete
#   5378  Simulated process instance         NaN         NaN             complete
#   5379  Simulated process instance         NaN         NaN             complete
#   5380  Simulated process instance        True         NaN             complete
#   5381  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   5370            NaN       NaN
#   5371            NaN        T2
#   5372            NaN       NaN
#   5373            NaN       NaN
#   5374            0.0       NaN
#   5375            NaN       NaN
#   5376            NaN       NaN
#   5377            0.0       NaN
#   5378            NaN       NaN
#   5379            NaN       NaN
#   5380            0.0       NaN
#   5381            0.0       NaN  ),
#  (8,
#         Case ID         Activity  Resource          Start Timestamp  \
#   6162        8         Register    System  1970/01/02 18:02:00.000
#   6163        8   Analyze Defect   Tester4  1970/01/02 18:02:00.000
#   6164        8  Repair (Simple)  SolverS1  1970/01/02 18:18:00.000
#   6165        8      Test Repair   Tester5  1970/01/02 18:23:00.000
#   6166        8   Restart Repair    System  1970/01/02 18:33:00.000
#   6167        8  Repair (Simple)  SolverS3  1970/01/02 18:33:00.000
#   6168        8      Test Repair   Tester2  1970/01/02 18:44:00.000
#   6169        8      Inform User    System  1970/01/02 18:48:00.000
#   6170        8   Archive Repair    System  1970/01/02 19:00:00.000
#
#              Complete Timestamp     Variant  Variant index  \
#   6162  1970/01/02 18:02:00.000  Variant 11             11
#   6163  1970/01/02 18:08:00.000  Variant 11             11
#   6164  1970/01/02 18:23:00.000  Variant 11             11
#   6165  1970/01/02 18:28:00.000  Variant 11             11
#   6166  1970/01/02 18:33:00.000  Variant 11             11
#   6167  1970/01/02 18:44:00.000  Variant 11             11
#   6168  1970/01/02 18:52:00.000  Variant 11             11
#   6169  1970/01/02 18:48:00.000  Variant 11             11
#   6170  1970/01/02 19:00:00.000  Variant 11             11
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   6162  Simulated process instance         NaN         NaN             complete
#   6163  Simulated process instance         NaN         3.0             complete
#   6164  Simulated process instance         NaN         NaN             complete
#   6165  Simulated process instance       False         NaN             complete
#   6166  Simulated process instance         NaN         NaN             complete
#   6167  Simulated process instance         NaN         NaN             complete
#   6168  Simulated process instance        True         NaN             complete
#   6169  Simulated process instance         NaN         NaN             complete
#   6170  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   6162            NaN       NaN
#   6163            NaN        T3
#   6164            NaN       NaN
#   6165            1.0       NaN
#   6166            NaN       NaN
#   6167            NaN       NaN
#   6168            2.0       NaN
#   6169            NaN       NaN
#   6170            2.0       NaN  ),
#  (9,
#         Case ID         Activity  Resource          Start Timestamp  \
#   6951        9         Register    System  1970/01/01 21:55:00.000
#   6952        9   Analyze Defect   Tester3  1970/01/01 21:55:00.000
#   6953        9  Repair (Simple)  SolverS3  1970/01/01 22:23:00.000
#   6954        9      Test Repair   Tester5  1970/01/01 22:34:00.000
#   6955        9      Inform User    System  1970/01/01 22:52:00.000
#   6956        9   Archive Repair    System  1970/01/01 22:52:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   6951  1970/01/01 21:55:00.000  Variant 3              3
#   6952  1970/01/01 22:02:00.000  Variant 3              3
#   6953  1970/01/01 22:34:00.000  Variant 3              3
#   6954  1970/01/01 22:41:00.000  Variant 3              3
#   6955  1970/01/01 22:52:00.000  Variant 3              3
#   6956  1970/01/01 22:52:00.000  Variant 3              3
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   6951  Simulated process instance         NaN         NaN             complete
#   6952  Simulated process instance         NaN         3.0             complete
#   6953  Simulated process instance         NaN         NaN             complete
#   6954  Simulated process instance        True         NaN             complete
#   6955  Simulated process instance         NaN         NaN             complete
#   6956  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   6951            NaN       NaN
#   6952            NaN        T3
#   6953            NaN       NaN
#   6954            1.0       NaN
#   6955            NaN       NaN
#   6956            1.0       NaN  ),
#  (10,
#       Case ID         Activity  Resource          Start Timestamp  \
#   6        10         Register    System  1970/01/01 12:09:00.000
#   7        10   Analyze Defect   Tester2  1970/01/01 12:09:00.000
#   8        10  Repair (Simple)  SolverS1  1970/01/01 12:35:00.000
#   9        10      Test Repair   Tester6  1970/01/01 12:42:00.000
#   10       10   Restart Repair    System  1970/01/01 12:54:00.000
#   11       10  Repair (Simple)  SolverS2  1970/01/01 12:54:00.000
#   12       10      Inform User    System  1970/01/01 12:55:00.000
#   13       10      Test Repair   Tester4  1970/01/01 13:03:00.000
#   14       10   Archive Repair    System  1970/01/01 13:14:00.000
#
#            Complete Timestamp    Variant  Variant index  \
#   6   1970/01/01 12:09:00.000  Variant 8              8
#   7   1970/01/01 12:15:00.000  Variant 8              8
#   8   1970/01/01 12:42:00.000  Variant 8              8
#   9   1970/01/01 12:48:00.000  Variant 8              8
#   10  1970/01/01 12:54:00.000  Variant 8              8
#   11  1970/01/01 13:03:00.000  Variant 8              8
#   12  1970/01/01 12:55:00.000  Variant 8              8
#   13  1970/01/01 13:09:00.000  Variant 8              8
#   14  1970/01/01 13:14:00.000  Variant 8              8
#
#               (case) description defectFixed  defectType lifecycle:transition  \
#   6   Simulated process instance         NaN         NaN             complete
#   7   Simulated process instance         NaN         3.0             complete
#   8   Simulated process instance         NaN         NaN             complete
#   9   Simulated process instance       False         NaN             complete
#   10  Simulated process instance         NaN         NaN             complete
#   11  Simulated process instance         NaN         NaN             complete
#   12  Simulated process instance         NaN         NaN             complete
#   13  Simulated process instance        True         NaN             complete
#   14  Simulated process instance        True         NaN             complete
#
#       numberRepairs phoneType
#   6             NaN       NaN
#   7             NaN        T1
#   8             NaN       NaN
#   9             1.0       NaN
#   10            NaN       NaN
#   11            NaN       NaN
#   12            NaN       NaN
#   13            2.0       NaN
#   14            2.0       NaN  ),
#  (11,
#        Case ID          Activity  Resource          Start Timestamp  \
#   643       11          Register    System  1970/01/02 16:51:00.000
#   644       11    Analyze Defect   Tester1  1970/01/02 16:51:00.000
#   645       11  Repair (Complex)  SolverC3  1970/01/02 17:04:00.000
#   646       11       Inform User    System  1970/01/02 17:16:00.000
#   647       11       Test Repair   Tester2  1970/01/02 17:52:00.000
#   648       11    Archive Repair    System  1970/01/02 18:06:00.000
#
#             Complete Timestamp    Variant  Variant index  \
#   643  1970/01/02 16:51:00.000  Variant 1              1
#   644  1970/01/02 16:58:00.000  Variant 1              1
#   645  1970/01/02 17:52:00.000  Variant 1              1
#   646  1970/01/02 17:16:00.000  Variant 1              1
#   647  1970/01/02 18:01:00.000  Variant 1              1
#   648  1970/01/02 18:06:00.000  Variant 1              1
#
#                (case) description defectFixed  defectType lifecycle:transition  \
#   643  Simulated process instance         NaN         NaN             complete
#   644  Simulated process instance         NaN        10.0             complete
#   645  Simulated process instance         NaN         NaN             complete
#   646  Simulated process instance         NaN         NaN             complete
#   647  Simulated process instance        True         NaN             complete
#   648  Simulated process instance        True         NaN             complete
#
#        numberRepairs phoneType
#   643            NaN       NaN
#   644            NaN        T3
#   645            NaN       NaN
#   646            NaN       NaN
#   647            0.0       NaN
#   648            0.0       NaN  ),
#  (12,
#        Case ID         Activity  Resource          Start Timestamp  \
#   786       12         Register    System  1970/01/01 15:12:00.000
#   787       12   Analyze Defect   Tester4  1970/01/01 15:12:00.000
#   788       12  Repair (Simple)  SolverS1  1970/01/01 15:37:00.000
#   789       12      Test Repair   Tester1  1970/01/01 15:44:00.000
#   790       12   Restart Repair    System  1970/01/01 16:02:00.000
#   791       12  Repair (Simple)  SolverS3  1970/01/01 16:02:00.000
#   792       12      Inform User    System  1970/01/01 16:10:00.000
#   793       12      Test Repair   Tester3  1970/01/01 16:19:00.000
#   794       12   Archive Repair    System  1970/01/01 16:36:00.000
#
#             Complete Timestamp    Variant  Variant index  \
#   786  1970/01/01 15:12:00.000  Variant 8              8
#   787  1970/01/01 15:22:00.000  Variant 8              8
#   788  1970/01/01 15:44:00.000  Variant 8              8
#   789  1970/01/01 15:54:00.000  Variant 8              8
#   790  1970/01/01 16:02:00.000  Variant 8              8
#   791  1970/01/01 16:19:00.000  Variant 8              8
#   792  1970/01/01 16:10:00.000  Variant 8              8
#   793  1970/01/01 16:26:00.000  Variant 8              8
#   794  1970/01/01 16:36:00.000  Variant 8              8
#
#                (case) description defectFixed  defectType lifecycle:transition  \
#   786  Simulated process instance         NaN         NaN             complete
#   787  Simulated process instance         NaN         2.0             complete
#   788  Simulated process instance         NaN         NaN             complete
#   789  Simulated process instance       False         NaN             complete
#   790  Simulated process instance         NaN         NaN             complete
#   791  Simulated process instance         NaN         NaN             complete
#   792  Simulated process instance         NaN         NaN             complete
#   793  Simulated process instance        True         NaN             complete
#   794  Simulated process instance        True         NaN             complete
#
#        numberRepairs phoneType
#   786            NaN       NaN
#   787            NaN        T3
#   788            NaN       NaN
#   789            1.0       NaN
#   790            NaN       NaN
#   791            NaN       NaN
#   792            NaN       NaN
#   793            2.0       NaN
#   794            2.0       NaN  ),
#  (13,
#        Case ID          Activity  Resource          Start Timestamp  \
#   870       13          Register    System  1970/01/01 12:35:00.000
#   871       13    Analyze Defect   Tester6  1970/01/01 12:35:00.000
#   872       13  Repair (Complex)  SolverC3  1970/01/01 13:05:00.000
#   873       13       Inform User    System  1970/01/01 13:25:00.000
#   874       13       Test Repair   Tester4  1970/01/01 13:45:00.000
#   875       13    Archive Repair    System  1970/01/01 14:01:00.000
#
#             Complete Timestamp    Variant  Variant index  \
#   870  1970/01/01 12:35:00.000  Variant 1              1
#   871  1970/01/01 12:42:00.000  Variant 1              1
#   872  1970/01/01 13:45:00.000  Variant 1              1
#   873  1970/01/01 13:25:00.000  Variant 1              1
#   874  1970/01/01 13:54:00.000  Variant 1              1
#   875  1970/01/01 14:01:00.000  Variant 1              1
#
#                (case) description defectFixed  defectType lifecycle:transition  \
#   870  Simulated process instance         NaN         NaN             complete
#   871  Simulated process instance         NaN         7.0             complete
#   872  Simulated process instance         NaN         NaN             complete
#   873  Simulated process instance         NaN         NaN             complete
#   874  Simulated process instance        True         NaN             complete
#   875  Simulated process instance        True         NaN             complete
#
#        numberRepairs phoneType
#   870            NaN       NaN
#   871            NaN        T1
#   872            NaN       NaN
#   873            NaN       NaN
#   874            0.0       NaN
#   875            0.0       NaN  ),
#  (14,
#        Case ID          Activity  Resource          Start Timestamp  \
#   960       14          Register    System  1970/01/02 18:03:00.000
#   961       14    Analyze Defect   Tester1  1970/01/02 18:03:00.000
#   962       14  Repair (Complex)  SolverC2  1970/01/02 18:23:00.000
#   963       14       Test Repair   Tester3  1970/01/02 18:33:00.000
#   964       14    Restart Repair    System  1970/01/02 18:46:00.000
#   965       14  Repair (Complex)  SolverC3  1970/01/02 18:46:00.000
#   966       14       Inform User    System  1970/01/02 18:56:00.000
#   967       14       Test Repair   Tester6  1970/01/02 19:31:00.000
#   968       14    Archive Repair    System  1970/01/02 19:45:00.000
#
#             Complete Timestamp     Variant  Variant index  \
#   960  1970/01/02 18:03:00.000  Variant 19             19
#   961  1970/01/02 18:12:00.000  Variant 19             19
#   962  1970/01/02 18:33:00.000  Variant 19             19
#   963  1970/01/02 18:40:00.000  Variant 19             19
#   964  1970/01/02 18:46:00.000  Variant 19             19
#   965  1970/01/02 19:31:00.000  Variant 19             19
#   966  1970/01/02 18:56:00.000  Variant 19             19
#   967  1970/01/02 19:37:00.000  Variant 19             19
#   968  1970/01/02 19:45:00.000  Variant 19             19
#
#                (case) description defectFixed  defectType lifecycle:transition  \
#   960  Simulated process instance         NaN         NaN             complete
#   961  Simulated process instance         NaN         8.0             complete
#   962  Simulated process instance         NaN         NaN             complete
#   963  Simulated process instance       False         NaN             complete
#   964  Simulated process instance         NaN         NaN             complete
#   965  Simulated process instance         NaN         NaN             complete
#   966  Simulated process instance         NaN         NaN             complete
#   967  Simulated process instance        True         NaN             complete
#   968  Simulated process instance        True         NaN             complete
#
#        numberRepairs phoneType
#   960            NaN       NaN
#   961            NaN        T3
#   962            NaN       NaN
#   963            0.0       NaN
#   964            NaN       NaN
#   965            NaN       NaN
#   966            NaN       NaN
#   967            0.0       NaN
#   968            0.0       NaN  ),
#  (15,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1038       15          Register    System  1970/01/01 11:16:00.000
#   1039       15    Analyze Defect   Tester2  1970/01/01 11:16:00.000
#   1040       15  Repair (Complex)  SolverC3  1970/01/01 11:29:00.000
#   1041       15       Inform User    System  1970/01/01 11:43:00.000
#   1042       15       Test Repair   Tester1  1970/01/01 12:16:00.000
#   1043       15    Archive Repair    System  1970/01/01 12:31:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   1038  1970/01/01 11:16:00.000  Variant 1              1
#   1039  1970/01/01 11:22:00.000  Variant 1              1
#   1040  1970/01/01 12:16:00.000  Variant 1              1
#   1041  1970/01/01 11:43:00.000  Variant 1              1
#   1042  1970/01/01 12:25:00.000  Variant 1              1
#   1043  1970/01/01 12:31:00.000  Variant 1              1
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1038  Simulated process instance         NaN         NaN             complete
#   1039  Simulated process instance         NaN         7.0             complete
#   1040  Simulated process instance         NaN         NaN             complete
#   1041  Simulated process instance         NaN         NaN             complete
#   1042  Simulated process instance        True         NaN             complete
#   1043  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1038            NaN       NaN
#   1039            NaN        T3
#   1040            NaN       NaN
#   1041            NaN       NaN
#   1042            0.0       NaN
#   1043            0.0       NaN  ),
#  (16,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1122       16          Register    System  1970/01/02 22:31:00.000
#   1123       16    Analyze Defect   Tester5  1970/01/02 22:31:00.000
#   1124       16  Repair (Complex)  SolverC1  1970/01/02 22:49:00.000
#   1125       16       Test Repair   Tester5  1970/01/02 23:05:00.000
#   1126       16       Inform User    System  1970/01/02 23:17:00.000
#   1127       16    Archive Repair    System  1970/01/02 23:23:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   1122  1970/01/02 22:31:00.000  Variant 2              2
#   1123  1970/01/02 22:38:00.000  Variant 2              2
#   1124  1970/01/02 23:05:00.000  Variant 2              2
#   1125  1970/01/02 23:15:00.000  Variant 2              2
#   1126  1970/01/02 23:17:00.000  Variant 2              2
#   1127  1970/01/02 23:23:00.000  Variant 2              2
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1122  Simulated process instance         NaN         NaN             complete
#   1123  Simulated process instance         NaN         7.0             complete
#   1124  Simulated process instance         NaN         NaN             complete
#   1125  Simulated process instance        True         NaN             complete
#   1126  Simulated process instance         NaN         NaN             complete
#   1127  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1122            NaN       NaN
#   1123            NaN        T2
#   1124            NaN       NaN
#   1125            0.0       NaN
#   1126            NaN       NaN
#   1127            0.0       NaN  ),
#  (17,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1203       17          Register    System  1970/01/02 17:11:00.000
#   1204       17    Analyze Defect   Tester4  1970/01/02 17:11:00.000
#   1205       17  Repair (Complex)  SolverC1  1970/01/02 17:23:00.000
#   1206       17       Test Repair   Tester4  1970/01/02 17:42:00.000
#   1207       17       Inform User    System  1970/01/02 17:56:00.000
#   1208       17    Restart Repair    System  1970/01/02 17:58:00.000
#   1209       17  Repair (Complex)  SolverC2  1970/01/02 17:58:00.000
#   1210       17       Test Repair   Tester4  1970/01/02 18:11:00.000
#   1211       17    Restart Repair    System  1970/01/02 18:29:00.000
#   1212       17  Repair (Complex)  SolverC1  1970/01/02 18:29:00.000
#   1213       17       Test Repair   Tester5  1970/01/02 18:48:00.000
#   1214       17    Archive Repair    System  1970/01/02 18:59:00.000
#
#              Complete Timestamp     Variant  Variant index  \
#   1203  1970/01/02 17:11:00.000  Variant 28             28
#   1204  1970/01/02 17:20:00.000  Variant 28             28
#   1205  1970/01/02 17:42:00.000  Variant 28             28
#   1206  1970/01/02 17:48:00.000  Variant 28             28
#   1207  1970/01/02 17:56:00.000  Variant 28             28
#   1208  1970/01/02 17:58:00.000  Variant 28             28
#   1209  1970/01/02 18:11:00.000  Variant 28             28
#   1210  1970/01/02 18:20:00.000  Variant 28             28
#   1211  1970/01/02 18:29:00.000  Variant 28             28
#   1212  1970/01/02 18:48:00.000  Variant 28             28
#   1213  1970/01/02 18:54:00.000  Variant 28             28
#   1214  1970/01/02 18:59:00.000  Variant 28             28
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1203  Simulated process instance         NaN         NaN             complete
#   1204  Simulated process instance         NaN        10.0             complete
#   1205  Simulated process instance         NaN         NaN             complete
#   1206  Simulated process instance       False         NaN             complete
#   1207  Simulated process instance         NaN         NaN             complete
#   1208  Simulated process instance         NaN         NaN             complete
#   1209  Simulated process instance         NaN         NaN             complete
#   1210  Simulated process instance       False         NaN             complete
#   1211  Simulated process instance         NaN         NaN             complete
#   1212  Simulated process instance         NaN         NaN             complete
#   1213  Simulated process instance        True         NaN             complete
#   1214  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1203            NaN       NaN
#   1204            NaN        T3
#   1205            NaN       NaN
#   1206            0.0       NaN
#   1207            NaN       NaN
#   1208            NaN       NaN
#   1209            NaN       NaN
#   1210            0.0       NaN
#   1211            NaN       NaN
#   1212            NaN       NaN
#   1213            0.0       NaN
#   1214            0.0       NaN  ),
#  (18,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1299       18          Register    System  1970/01/01 07:36:00.000
#   1300       18    Analyze Defect   Tester6  1970/01/01 07:36:00.000
#   1301       18   Repair (Simple)  SolverS1  1970/01/01 07:56:00.000
#   1302       18       Test Repair   Tester1  1970/01/01 08:03:00.000
#   1303       18    Restart Repair    System  1970/01/01 08:18:00.000
#   1304       18  Repair (Complex)  SolverC1  1970/01/01 08:18:00.000
#   1305       18       Inform User    System  1970/01/01 08:24:00.000
#   1306       18       Test Repair   Tester2  1970/01/01 08:35:00.000
#   1307       18    Archive Repair    System  1970/01/01 08:51:00.000
#
#              Complete Timestamp     Variant  Variant index  \
#   1299  1970/01/01 07:36:00.000  Variant 20             20
#   1300  1970/01/01 07:44:00.000  Variant 20             20
#   1301  1970/01/01 08:03:00.000  Variant 20             20
#   1302  1970/01/01 08:13:00.000  Variant 20             20
#   1303  1970/01/01 08:18:00.000  Variant 20             20
#   1304  1970/01/01 08:35:00.000  Variant 20             20
#   1305  1970/01/01 08:24:00.000  Variant 20             20
#   1306  1970/01/01 08:41:00.000  Variant 20             20
#   1307  1970/01/01 08:51:00.000  Variant 20             20
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1299  Simulated process instance         NaN         NaN             complete
#   1300  Simulated process instance         NaN         5.0             complete
#   1301  Simulated process instance         NaN         NaN             complete
#   1302  Simulated process instance       False         NaN             complete
#   1303  Simulated process instance         NaN         NaN             complete
#   1304  Simulated process instance         NaN         NaN             complete
#   1305  Simulated process instance         NaN         NaN             complete
#   1306  Simulated process instance        True         NaN             complete
#   1307  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1299            NaN       NaN
#   1300            NaN        T3
#   1301            NaN       NaN
#   1302            1.0       NaN
#   1303            NaN       NaN
#   1304            NaN       NaN
#   1305            NaN       NaN
#   1306            1.0       NaN
#   1307            1.0       NaN  ),
#  (19,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1377       19          Register    System  1970/01/02 04:33:00.000
#   1378       19    Analyze Defect   Tester6  1970/01/02 04:33:00.000
#   1379       19       Inform User    System  1970/01/02 04:58:00.000
#   1380       19  Repair (Complex)  SolverC3  1970/01/02 04:58:00.000
#   1381       19       Test Repair   Tester1  1970/01/02 05:46:00.000
#   1382       19    Archive Repair    System  1970/01/02 06:00:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   1377  1970/01/02 04:33:00.000  Variant 4              4
#   1378  1970/01/02 04:39:00.000  Variant 4              4
#   1379  1970/01/02 04:58:00.000  Variant 4              4
#   1380  1970/01/02 05:46:00.000  Variant 4              4
#   1381  1970/01/02 05:52:00.000  Variant 4              4
#   1382  1970/01/02 06:00:00.000  Variant 4              4
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1377  Simulated process instance         NaN         NaN             complete
#   1378  Simulated process instance         NaN         9.0             complete
#   1379  Simulated process instance         NaN         NaN             complete
#   1380  Simulated process instance         NaN         NaN             complete
#   1381  Simulated process instance        True         NaN             complete
#   1382  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1377            NaN       NaN
#   1378            NaN        T3
#   1379            NaN       NaN
#   1380            NaN       NaN
#   1381            0.0       NaN
#   1382            0.0       NaN  ),
#  (20,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1458       20          Register    System  1970/01/02 10:02:00.000
#   1459       20    Analyze Defect   Tester5  1970/01/02 10:02:00.000
#   1460       20  Repair (Complex)  SolverC3  1970/01/02 10:13:00.000
#   1461       20       Inform User    System  1970/01/02 10:33:00.000
#   1462       20       Test Repair   Tester5  1970/01/02 10:54:00.000
#   1463       20    Archive Repair    System  1970/01/02 11:08:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   1458  1970/01/02 10:02:00.000  Variant 1              1
#   1459  1970/01/02 10:10:00.000  Variant 1              1
#   1460  1970/01/02 10:54:00.000  Variant 1              1
#   1461  1970/01/02 10:33:00.000  Variant 1              1
#   1462  1970/01/02 11:03:00.000  Variant 1              1
#   1463  1970/01/02 11:08:00.000  Variant 1              1
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1458  Simulated process instance         NaN         NaN             complete
#   1459  Simulated process instance         NaN         8.0             complete
#   1460  Simulated process instance         NaN         NaN             complete
#   1461  Simulated process instance         NaN         NaN             complete
#   1462  Simulated process instance        True         NaN             complete
#   1463  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1458            NaN       NaN
#   1459            NaN        T1
#   1460            NaN       NaN
#   1461            NaN       NaN
#   1462            0.0       NaN
#   1463            0.0       NaN  ),
#  (21,
#         Case ID         Activity  Resource          Start Timestamp  \
#   1536       21         Register    System  1970/01/02 01:55:00.000
#   1537       21   Analyze Defect   Tester6  1970/01/02 01:55:00.000
#   1538       21  Repair (Simple)  SolverS1  1970/01/02 02:21:00.000
#   1539       21      Test Repair   Tester6  1970/01/02 02:26:00.000
#   1540       21      Inform User    System  1970/01/02 02:30:00.000
#   1541       21   Restart Repair    System  1970/01/02 02:44:00.000
#   1542       21  Repair (Simple)  SolverS3  1970/01/02 02:44:00.000
#   1543       21      Test Repair   Tester4  1970/01/02 02:58:00.000
#   1544       21   Archive Repair    System  1970/01/02 03:16:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   1536  1970/01/02 01:55:00.000  Variant 7              7
#   1537  1970/01/02 02:05:00.000  Variant 7              7
#   1538  1970/01/02 02:26:00.000  Variant 7              7
#   1539  1970/01/02 02:34:00.000  Variant 7              7
#   1540  1970/01/02 02:30:00.000  Variant 7              7
#   1541  1970/01/02 02:44:00.000  Variant 7              7
#   1542  1970/01/02 02:58:00.000  Variant 7              7
#   1543  1970/01/02 03:08:00.000  Variant 7              7
#   1544  1970/01/02 03:16:00.000  Variant 7              7
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1536  Simulated process instance         NaN         NaN             complete
#   1537  Simulated process instance         NaN         4.0             complete
#   1538  Simulated process instance         NaN         NaN             complete
#   1539  Simulated process instance       False         NaN             complete
#   1540  Simulated process instance         NaN         NaN             complete
#   1541  Simulated process instance         NaN         NaN             complete
#   1542  Simulated process instance         NaN         NaN             complete
#   1543  Simulated process instance        True         NaN             complete
#   1544  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1536            NaN       NaN
#   1537            NaN        T1
#   1538            NaN       NaN
#   1539            1.0       NaN
#   1540            NaN       NaN
#   1541            NaN       NaN
#   1542            NaN       NaN
#   1543            2.0       NaN
#   1544            2.0       NaN  ),
#  (22,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1614       22          Register    System  1970/01/02 09:25:00.000
#   1615       22    Analyze Defect   Tester4  1970/01/02 09:25:00.000
#   1616       22  Repair (Complex)  SolverC1  1970/01/02 10:01:00.000
#   1617       22       Inform User    System  1970/01/02 10:05:00.000
#   1618       22       Test Repair   Tester5  1970/01/02 10:16:00.000
#   1619       22    Archive Repair    System  1970/01/02 10:35:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   1614  1970/01/02 09:25:00.000  Variant 1              1
#   1615  1970/01/02 09:34:00.000  Variant 1              1
#   1616  1970/01/02 10:16:00.000  Variant 1              1
#   1617  1970/01/02 10:05:00.000  Variant 1              1
#   1618  1970/01/02 10:26:00.000  Variant 1              1
#   1619  1970/01/02 10:35:00.000  Variant 1              1
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1614  Simulated process instance         NaN         NaN             complete
#   1615  Simulated process instance         NaN         8.0             complete
#   1616  Simulated process instance         NaN         NaN             complete
#   1617  Simulated process instance         NaN         NaN             complete
#   1618  Simulated process instance        True         NaN             complete
#   1619  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1614            NaN       NaN
#   1615            NaN        T2
#   1616            NaN       NaN
#   1617            NaN       NaN
#   1618            0.0       NaN
#   1619            0.0       NaN  ),
#  (23,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1692       23          Register    System  1970/01/02 23:17:00.000
#   1693       23    Analyze Defect   Tester6  1970/01/02 23:17:00.000
#   1694       23  Repair (Complex)  SolverC2  1970/01/02 23:51:00.000
#   1695       23       Test Repair   Tester5  1970/01/03 00:02:00.000
#   1696       23       Inform User    System  1970/01/03 00:05:00.000
#   1697       23    Archive Repair    System  1970/01/03 00:16:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   1692  1970/01/02 23:17:00.000  Variant 2              2
#   1693  1970/01/02 23:22:00.000  Variant 2              2
#   1694  1970/01/03 00:02:00.000  Variant 2              2
#   1695  1970/01/03 00:09:00.000  Variant 2              2
#   1696  1970/01/03 00:05:00.000  Variant 2              2
#   1697  1970/01/03 00:16:00.000  Variant 2              2
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   1692  Simulated process instance         NaN         NaN             complete
#   1693  Simulated process instance         NaN         5.0             complete
#   1694  Simulated process instance         NaN         NaN             complete
#   1695  Simulated process instance        True         NaN             complete
#   1696  Simulated process instance         NaN         NaN             complete
#   1697  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   1692            NaN       NaN
#   1693            NaN        T3
#   1694            NaN       NaN
#   1695            0.0       NaN
#   1696            NaN       NaN
#   1697            0.0       NaN  ),
#  (24,
#         Case ID          Activity  Resource          Start Timestamp  \
#   1764       24          Register    System  1970/01/02 01:32:00.000
# ...
#   7687      993    Restart Repair    System  1970/01/21 09:56:00.000
#   7688      993  Repair (Complex)  SolverC3  1970/01/21 09:56:00.000
#   7689      993       Inform User    System  1970/01/21 10:03:00.000
#   7690      993       Test Repair   Tester4  1970/01/21 10:37:00.000
#   7691      993    Archive Repair    System  1970/01/21 10:53:00.000
#
#              Complete Timestamp     Variant  Variant index  \
#   7683  1970/01/21 09:08:00.000  Variant 19             19
#   7684  1970/01/21 09:13:00.000  Variant 19             19
#   7685  1970/01/21 09:38:00.000  Variant 19             19
#   7686  1970/01/21 09:48:00.000  Variant 19             19
#   7687  1970/01/21 09:56:00.000  Variant 19             19
#   7688  1970/01/21 10:37:00.000  Variant 19             19
#   7689  1970/01/21 10:03:00.000  Variant 19             19
#   7690  1970/01/21 10:46:00.000  Variant 19             19
#   7691  1970/01/21 10:53:00.000  Variant 19             19
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   7683  Simulated process instance         NaN         NaN             complete
#   7684  Simulated process instance         NaN        10.0             complete
#   7685  Simulated process instance         NaN         NaN             complete
#   7686  Simulated process instance       False         NaN             complete
#   7687  Simulated process instance         NaN         NaN             complete
#   7688  Simulated process instance         NaN         NaN             complete
#   7689  Simulated process instance         NaN         NaN             complete
#   7690  Simulated process instance        True         NaN             complete
#   7691  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   7683            NaN       NaN
#   7684            NaN        T1
#   7685            NaN       NaN
#   7686            0.0       NaN
#   7687            NaN       NaN
#   7688            NaN       NaN
#   7689            NaN       NaN
#   7690            0.0       NaN
#   7691            0.0       NaN  ),
#  (994,
#         Case ID         Activity  Resource          Start Timestamp  \
#   7692      994         Register    System  1970/01/21 19:56:00.000
#   7693      994   Analyze Defect   Tester1  1970/01/21 19:56:00.000
#   7694      994  Repair (Simple)  SolverS2  1970/01/21 20:11:00.000
#   7695      994      Test Repair   Tester5  1970/01/21 20:17:00.000
#   7696      994   Restart Repair    System  1970/01/21 20:36:00.000
#   7697      994  Repair (Simple)  SolverS3  1970/01/21 20:36:00.000
#   7698      994      Test Repair   Tester3  1970/01/21 20:49:00.000
#   7699      994      Inform User    System  1970/01/21 20:50:00.000
#   7700      994   Archive Repair    System  1970/01/21 21:06:00.000
#
#              Complete Timestamp     Variant  Variant index  \
#   7692  1970/01/21 19:56:00.000  Variant 11             11
#   7693  1970/01/21 20:03:00.000  Variant 11             11
#   7694  1970/01/21 20:17:00.000  Variant 11             11
#   7695  1970/01/21 20:27:00.000  Variant 11             11
#   7696  1970/01/21 20:36:00.000  Variant 11             11
#   7697  1970/01/21 20:49:00.000  Variant 11             11
#   7698  1970/01/21 20:59:00.000  Variant 11             11
#   7699  1970/01/21 20:50:00.000  Variant 11             11
#   7700  1970/01/21 21:06:00.000  Variant 11             11
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   7692  Simulated process instance         NaN         NaN             complete
#   7693  Simulated process instance         NaN         6.0             complete
#   7694  Simulated process instance         NaN         NaN             complete
#   7695  Simulated process instance       False         NaN             complete
#   7696  Simulated process instance         NaN         NaN             complete
#   7697  Simulated process instance         NaN         NaN             complete
#   7698  Simulated process instance        True         NaN             complete
#   7699  Simulated process instance         NaN         NaN             complete
#   7700  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   7692            NaN       NaN
#   7693            NaN        T2
#   7694            NaN       NaN
#   7695            1.0       NaN
#   7696            NaN       NaN
#   7697            NaN       NaN
#   7698            2.0       NaN
#   7699            NaN       NaN
#   7700            2.0       NaN  ),
#  (995,
#         Case ID          Activity  Resource          Start Timestamp  \
#   7701      995          Register    System  1970/01/21 14:33:00.000
#   7702      995    Analyze Defect   Tester5  1970/01/21 14:33:00.000
#   7703      995  Repair (Complex)  SolverC1  1970/01/21 14:54:00.000
#   7704      995       Inform User    System  1970/01/21 15:01:00.000
#   7705      995       Test Repair   Tester4  1970/01/21 15:07:00.000
#   7706      995    Archive Repair    System  1970/01/21 15:21:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   7701  1970/01/21 14:33:00.000  Variant 1              1
#   7702  1970/01/21 14:40:00.000  Variant 1              1
#   7703  1970/01/21 15:07:00.000  Variant 1              1
#   7704  1970/01/21 15:01:00.000  Variant 1              1
#   7705  1970/01/21 15:13:00.000  Variant 1              1
#   7706  1970/01/21 15:21:00.000  Variant 1              1
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   7701  Simulated process instance         NaN         NaN             complete
#   7702  Simulated process instance         NaN         7.0             complete
#   7703  Simulated process instance         NaN         NaN             complete
#   7704  Simulated process instance         NaN         NaN             complete
#   7705  Simulated process instance        True         NaN             complete
#   7706  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   7701            NaN       NaN
#   7702            NaN        T3
#   7703            NaN       NaN
#   7704            NaN       NaN
#   7705            0.0       NaN
#   7706            0.0       NaN  ),
#  (996,
#         Case ID          Activity  Resource          Start Timestamp  \
#   7707      996          Register    System  1970/01/22 16:35:00.000
#   7708      996    Analyze Defect   Tester4  1970/01/22 16:35:00.000
#   7709      996  Repair (Complex)  SolverC2  1970/01/22 16:55:00.000
#   7710      996       Inform User    System  1970/01/22 17:04:00.000
#   7711      996       Test Repair   Tester3  1970/01/22 17:06:00.000
#   7712      996    Archive Repair    System  1970/01/22 17:23:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   7707  1970/01/22 16:35:00.000  Variant 1              1
#   7708  1970/01/22 16:43:00.000  Variant 1              1
#   7709  1970/01/22 17:06:00.000  Variant 1              1
#   7710  1970/01/22 17:04:00.000  Variant 1              1
#   7711  1970/01/22 17:13:00.000  Variant 1              1
#   7712  1970/01/22 17:23:00.000  Variant 1              1
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   7707  Simulated process instance         NaN         NaN             complete
#   7708  Simulated process instance         NaN         9.0             complete
#   7709  Simulated process instance         NaN         NaN             complete
#   7710  Simulated process instance         NaN         NaN             complete
#   7711  Simulated process instance        True         NaN             complete
#   7712  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   7707            NaN       NaN
#   7708            NaN        T2
#   7709            NaN       NaN
#   7710            NaN       NaN
#   7711            0.0       NaN
#   7712            0.0       NaN  ),
#  (997,
#         Case ID          Activity  Resource          Start Timestamp  \
#   7713      997          Register    System  1970/01/21 19:16:00.000
#   7714      997    Analyze Defect   Tester1  1970/01/21 19:16:00.000
#   7715      997  Repair (Complex)  SolverC1  1970/01/21 19:35:00.000
#   7716      997       Test Repair   Tester6  1970/01/21 19:47:00.000
#   7717      997       Inform User    System  1970/01/21 20:06:00.000
#   7718      997    Archive Repair    System  1970/01/21 20:06:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   7713  1970/01/21 19:16:00.000  Variant 2              2
#   7714  1970/01/21 19:25:00.000  Variant 2              2
#   7715  1970/01/21 19:47:00.000  Variant 2              2
#   7716  1970/01/21 19:56:00.000  Variant 2              2
#   7717  1970/01/21 20:06:00.000  Variant 2              2
#   7718  1970/01/21 20:06:00.000  Variant 2              2
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   7713  Simulated process instance         NaN         NaN             complete
#   7714  Simulated process instance         NaN        10.0             complete
#   7715  Simulated process instance         NaN         NaN             complete
#   7716  Simulated process instance        True         NaN             complete
#   7717  Simulated process instance         NaN         NaN             complete
#   7718  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   7713            NaN       NaN
#   7714            NaN        T2
#   7715            NaN       NaN
#   7716            0.0       NaN
#   7717            NaN       NaN
#   7718            0.0       NaN  ),
#  (998,
#         Case ID          Activity  Resource          Start Timestamp  \
#   7719      998          Register    System  1970/01/22 07:53:00.000
#   7720      998    Analyze Defect   Tester1  1970/01/22 07:53:00.000
#   7721      998  Repair (Complex)  SolverC3  1970/01/22 08:07:00.000
#   7722      998       Inform User    System  1970/01/22 08:42:00.000
#   7723      998       Test Repair   Tester4  1970/01/22 08:49:00.000
#   7724      998    Archive Repair    System  1970/01/22 09:03:00.000
#
#              Complete Timestamp    Variant  Variant index  \
#   7719  1970/01/22 07:53:00.000  Variant 1              1
#   7720  1970/01/22 08:01:00.000  Variant 1              1
#   7721  1970/01/22 08:49:00.000  Variant 1              1
#   7722  1970/01/22 08:42:00.000  Variant 1              1
#   7723  1970/01/22 08:56:00.000  Variant 1              1
#   7724  1970/01/22 09:03:00.000  Variant 1              1
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   7719  Simulated process instance         NaN         NaN             complete
#   7720  Simulated process instance         NaN         7.0             complete
#   7721  Simulated process instance         NaN         NaN             complete
#   7722  Simulated process instance         NaN         NaN             complete
#   7723  Simulated process instance        True         NaN             complete
#   7724  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   7719            NaN       NaN
#   7720            NaN        T3
#   7721            NaN       NaN
#   7722            NaN       NaN
#   7723            0.0       NaN
#   7724            0.0       NaN  ),
#  (999,
#         Case ID         Activity  Resource          Start Timestamp  \
#   7725      999         Register    System  1970/01/22 20:01:00.000
#   7726      999   Analyze Defect   Tester2  1970/01/22 20:01:00.000
#   7727      999  Repair (Simple)  SolverS2  1970/01/22 20:10:00.000
#   7728      999      Test Repair   Tester4  1970/01/22 20:22:00.000
#   7729      999   Restart Repair    System  1970/01/22 20:38:00.000
#   7730      999  Repair (Simple)  SolverS3  1970/01/22 20:38:00.000
#   7731      999      Test Repair   Tester2  1970/01/22 20:48:00.000
#   7732      999      Inform User    System  1970/01/22 20:56:00.000
#   7733      999   Archive Repair    System  1970/01/22 21:00:00.000
#
#              Complete Timestamp     Variant  Variant index  \
#   7725  1970/01/22 20:01:00.000  Variant 11             11
#   7726  1970/01/22 20:06:00.000  Variant 11             11
#   7727  1970/01/22 20:22:00.000  Variant 11             11
#   7728  1970/01/22 20:28:00.000  Variant 11             11
#   7729  1970/01/22 20:38:00.000  Variant 11             11
#   7730  1970/01/22 20:48:00.000  Variant 11             11
#   7731  1970/01/22 20:55:00.000  Variant 11             11
#   7732  1970/01/22 20:56:00.000  Variant 11             11
#   7733  1970/01/22 21:00:00.000  Variant 11             11
#
#                 (case) description defectFixed  defectType lifecycle:transition  \
#   7725  Simulated process instance         NaN         NaN             complete
#   7726  Simulated process instance         NaN         4.0             complete
#   7727  Simulated process instance         NaN         NaN             complete
#   7728  Simulated process instance       False         NaN             complete
#   7729  Simulated process instance         NaN         NaN             complete
#   7730  Simulated process instance         NaN         NaN             complete
#   7731  Simulated process instance        True         NaN             complete
#   7732  Simulated process instance         NaN         NaN             complete
#   7733  Simulated process instance        True         NaN             complete
#
#         numberRepairs phoneType
#   7725            NaN       NaN
#   7726            NaN        T3
#   7727            NaN       NaN
#   7728            1.0       NaN
#   7729            NaN       NaN
#   7730            NaN       NaN
#   7731            2.0       NaN
#   7732            NaN       NaN
#   7733            2.0       NaN  ),
#  (1000,
#       Case ID         Activity  Resource          Start Timestamp  \
#   21     1000         Register    System  1970/01/22 07:23:00.000
#   22     1000   Analyze Defect   Tester6  1970/01/22 07:23:00.000
#   23     1000  Repair (Simple)  SolverS3  1970/01/22 07:35:00.000
#   24     1000      Test Repair   Tester6  1970/01/22 07:49:00.000
#   25     1000      Inform User    System  1970/01/22 08:03:00.000
#   26     1000   Archive Repair    System  1970/01/22 08:08:00.000
#
#            Complete Timestamp    Variant  Variant index  \
#   21  1970/01/22 07:23:00.000  Variant 3              3
#   22  1970/01/22 07:28:00.000  Variant 3              3
#   23  1970/01/22 07:49:00.000  Variant 3              3
#   24  1970/01/22 07:58:00.000  Variant 3              3
#   25  1970/01/22 08:03:00.000  Variant 3              3
#   26  1970/01/22 08:08:00.000  Variant 3              3
#
#               (case) description defectFixed  defectType lifecycle:transition  \
#   21  Simulated process instance         NaN         NaN             complete
#   22  Simulated process instance         NaN         3.0             complete
#   23  Simulated process instance         NaN         NaN             complete
#   24  Simulated process instance        True         NaN             complete
#   25  Simulated process instance         NaN         NaN             complete
#   26  Simulated process instance        True         NaN             complete
#
#       numberRepairs phoneType
#   21            NaN       NaN
#   22            NaN        T3
#   23            NaN       NaN
#   24            1.0       NaN
#   25            NaN       NaN
#   26            1.0       NaN  ),
#  ...]

# %% [markdown]
# ## Useful Functions

# %% [markdown]
# **Compose** - helper function that is mathematical function composition
#
# **Merge** - merge function used to join the results of the *EventIdentifiers*

# %%
def compose(*functions):
    def inner(arg):
        for f in functions:
            arg = f(arg)
        return arg
    return inner

def merge(*structs):
    structs = list(filter(bool, structs))
    match structs[0]:
        case list():
            return reduce(op.add, structs)  # ? merge
        case dict():
            result = {}
            keys = set((key for struct in structs for key in struct.keys()))
            for key in keys:
                elems = (struct.get(key) for struct in structs if struct.get(key) is not None)
                result[key] = merge(*tuple(elems))
            return result
        case _:
            elems = set(structs)
            if len(elems) > 1:
                raise ValueError
            return elems[0]

# %%
'''
logExample.csv
purchasingExample.csv
repairExample.csv
sepsisExample.csv
'''

all_filenames = [
    'logExample.csv',
    'purchasingExample.csv',
    'repairExample.csv',
    'sepsisExample.csv',
    'first_ad.csv',
    'second_ad.csv',
]

to_filter = ['repairExample.csv', 'first_ad.csv', 'second_ad.csv'] or all_filenames[:]
used_filenames = list(filter(to_filter.__contains__, all_filenames))
dataframes = {filename: pd.read_csv(filename) for filename in used_filenames}

# %%
cols = [list(dataframe.columns) for dataframe in dataframes.values()]
for kind, columns in zip(used_filenames, cols):
    print(f'{kind:>22}: ', columns)
    print(f'{"- ":>25}', next((col for col in columns if 'case' in col.lower()), None))
    print(f'{"- ":>25}', next((col for col in columns if 'activ' in col.lower()), None))
    print(f'{"- ":>25}', [col for col in columns if 'timestamp' in col.lower() or 'date' in col.lower()])
# Out:
#      repairExample.csv:  ['Case ID', 'Activity', 'Resource', 'Start Timestamp', 'Complete Timestamp', 'Variant', 'Variant index', '(case) description', 'defectFixed', 'defectType', 'lifecycle:transition', 'numberRepairs', 'phoneType']
#                        -  Case ID
#                        -  Activity
#                        -  ['Start Timestamp', 'Complete Timestamp']
#           first_ad.csv:  ['Case ID', 'Activity', 'Start Timestamp', 'End Timestamp']
#                        -  Case ID
#                        -  Activity
#                        -  ['Start Timestamp', 'End Timestamp']
#          second_ad.csv:  ['Case ID', 'Activity', 'Start Timestamp', 'End Timestamp']
#                        -  Case ID
#                        -  Activity
#                        -  ['Start Timestamp', 'End Timestamp']

# %% [markdown]
# ## Processing

# %%
def map_names(dataframe):
    mapper = {
        'Complete Timestamp': 'End Timestamp',
        'Start Date': 'Start Timestamp',
        'End Date': 'End Timestamp',
    }
    renamed = dataframe.rename(columns=mapper)
    return renamed

def add_start_timestamp_if_needed(dataframe):
    dataframe = dataframe.copy()
    if 'Start Timestamp' not in dataframe:
        dataframe['Start Timestamp'] = dataframe['End Timestamp']
    return dataframe

def map_timestamps(dataframe):
    dataframe['Start Timestamp'] = pd.to_datetime(dataframe['Start Timestamp'])
    dataframe['End Timestamp'] = pd.to_datetime(dataframe['End Timestamp'])
    return dataframe

def add_duration(dataframe):
    dataframe['Duration'] = dataframe['Start Timestamp'] - dataframe['End Timestamp']
    return dataframe

normalise = compose(
    map_names,
    add_start_timestamp_if_needed,
    map_timestamps,
    add_duration,
)

dataframes = dict(zip(dataframes.keys(), map(normalise, dataframes.values())))

# %% [markdown]
# ## Pairing

# %% [markdown]
# ### Pairing Events
#
# With this function, we are pairing up 2 events that are sequential together for deeper analysis.
# For a single case where the sequence would be A -> B -> C -> D -> E, the function would return a dataframe with following information:
# | Pairs | Times | Mean | Standard Deviation|
# | --- | --- | --- | --- |
# | A, B | ALL POSSIBLE TIME LENGTHS OF EVENT A AS A LIST | MEAN(GIVEN LIST) | STD(GIVEN LIST) |
# | B, C | ALL POSSIBLE TIME LENGTHS OF EVENT A AS A LIST | MEAN(GIVEN LIST) | STD(GIVEN LIST) |
# | C, D | ALL POSSIBLE TIME LENGTHS OF EVENT A AS A LIST | MEAN(GIVEN LIST) | STD(GIVEN LIST) |
# | D, E | ALL POSSIBLE TIME LENGTHS OF EVENT A AS A LIST | MEAN(GIVEN LIST) | STD(GIVEN LIST) |
# | D, B | ALL POSSIBLE TIME LENGTHS OF EVENT A AS A LIST | MEAN(GIVEN LIST) | STD(GIVEN LIST) |

# %%
def get_seq_as_pairs(df):
    
    df.sort_values(by=['Case ID', 'Start Timestamp'], inplace=True)
    grouped = df.groupby('Case ID')
    
    result = []
    for case_id, group in grouped:
        activities = group['Activity'].tolist()
        start_times = group['Start Timestamp'].tolist()
        complete_times = group['End Timestamp'].tolist()
        case_result = [[from_activity, (te-t0).total_seconds(), to_activity] for from_activity, t0, te, to_activity in  zip(activities, start_times, complete_times, activities[1:])]
        result.append(case_result)
    
    pairs_time = {}
    for from_activity, period, to_activity in (case for row in result for case in row):
        pairs_time.setdefault((from_activity, to_activity), []).append(period)
    
    reshaped_data = {'pairs': [], 'times': []}
    for key, values in pairs_time.items():
        reshaped_data['pairs'].append(key)
        reshaped_data['times'].append(values)
    
    pairs_df = pd.DataFrame(reshaped_data)
    
    for index, row in pairs_df.iterrows():
        times_list = (row.iloc[1])
        pairs_df.at[index, 'mean'] = mean(times_list)
        pairs_df.at[index, 'std'] = np.std(times_list)
    
    return pairs_df

# %%
next(iter(dataframes.values()))
# Out:
#       Case ID          Activity  Resource     Start Timestamp  \
# 0           1          Register    System 1970-01-02 13:23:00
# 1           1    Analyze Defect   Tester3 1970-01-02 13:23:00
# 2           1  Repair (Complex)  SolverC1 1970-01-02 13:31:00
# 3           1       Test Repair   Tester3 1970-01-02 13:49:00
# 4           1       Inform User    System 1970-01-02 14:10:00
# ...       ...               ...       ...                 ...
# 7729      999    Restart Repair    System 1970-01-22 20:38:00
# 7730      999   Repair (Simple)  SolverS3 1970-01-22 20:38:00
# 7731      999       Test Repair   Tester2 1970-01-22 20:48:00
# 7732      999       Inform User    System 1970-01-22 20:56:00
# 7733      999    Archive Repair    System 1970-01-22 21:00:00
#
#            End Timestamp     Variant  Variant index  \
# 0    1970-01-02 13:23:00   Variant 2              2
# 1    1970-01-02 13:30:00   Variant 2              2
# 2    1970-01-02 13:49:00   Variant 2              2
# 3    1970-01-02 13:55:00   Variant 2              2
# 4    1970-01-02 14:10:00   Variant 2              2
# ...                  ...         ...            ...
# 7729 1970-01-22 20:38:00  Variant 11             11
# 7730 1970-01-22 20:48:00  Variant 11             11
# 7731 1970-01-22 20:55:00  Variant 11             11
# 7732 1970-01-22 20:56:00  Variant 11             11
# 7733 1970-01-22 21:00:00  Variant 11             11
#
#               (case) description defectFixed  defectType lifecycle:transition  \
# 0     Simulated process instance         NaN         NaN             complete
# 1     Simulated process instance         NaN         6.0             complete
# 2     Simulated process instance         NaN         NaN             complete
# 3     Simulated process instance        True         NaN             complete
# 4     Simulated process instance         NaN         NaN             complete
# ...                          ...         ...         ...                  ...
# 7729  Simulated process instance         NaN         NaN             complete
# 7730  Simulated process instance         NaN         NaN             complete
# 7731  Simulated process instance        True         NaN             complete
# 7732  Simulated process instance         NaN         NaN             complete
# 7733  Simulated process instance        True         NaN             complete
#
#       numberRepairs phoneType          Duration
# 0               NaN       NaN   0 days 00:00:00
# 1               NaN        T2 -1 days +23:53:00
# 2               NaN       NaN -1 days +23:42:00
# 3               0.0       NaN -1 days +23:54:00
# 4               NaN       NaN   0 days 00:00:00
# ...             ...       ...               ...
# 7729            NaN       NaN   0 days 00:00:00
# 7730            NaN       NaN -1 days +23:50:00
# 7731            2.0       NaN -1 days +23:53:00
# 7732            NaN       NaN   0 days 00:00:00
# 7733            2.0       NaN   0 days 00:00:00
#
# [7734 rows x 14 columns]

# %% [markdown]
# # Identifying

# %% [markdown]
# **SingleEventTypeIdentifier** is a class from which the rest of the classes inherit to give access to function avvailable in parent (**EventTypeIdentifier**)

# %%
class SingleEventTypeIdentifier:
    def __init__(self, parent, name: str = None):
        self.name = name or self.__class__.__name__.replace('EventIdentifier', '')
        self.parent = parent
        
    def identify(self, dataframe: pd.DataFrame, earlier_data: dict):
        raise NotImplementedErrror

# %% [markdown]
# **EventTypeIdentifier** - class that contains the identifiers for specific events and contains common logic

# %%
class EventTypeIdentifier:
    def __init__(self):
        self._dataframe: pd.DataFrame = None
        self.identifiers: list[SingleEventTypeIdentifier] = []
        self.paths = None
        self.cycles = None
        self.cyclied_paths = None

    @property
    def dataframe(self):
        return self._dataframe

    @dataframe.setter
    def dataframe(self, to_set):
        self._dataframe = to_set
        self.analyse()

    @property
    def n_activities(self):
        return len(df['Activity'].unique())

    def analyse(self, dataframe: pd.DataFrame = None):
        dataframe = dataframe or self.dataframe
        self.paths = self.get_paths(dataframe)
        self.analyse_cycles()

    def get_paths(self, dataframe):
        grouped_df = dataframe.groupby('Case ID')['Activity'].agg(list).reset_index()
        return tuple(set(map(tuple, grouped_df['Activity'])))

    def analyse_cycles(self, paths=None):
        paths = paths or self.paths
        paths_with_cycles = list(filter(lambda pc: pc[1], ((path, self.get_cycles(path)) for path in paths)))
        # self.cycles = list(unique_everseen((cycle for path, cycles in self.paths_with_cycles for cycle in cycles)))
        self.cyclied_paths = self.get_cyclied_paths(paths_with_cycles)
        self.cycles = self.get_normalised_cycles(self.cyclied_paths)
        # print('cyclied_paths')
        # for i, cyclied_path in enumerate(self.cyclied_paths):
        #     print(i, cyclied_path)
        # print('#'*20)
        # print('cycles')
        # for i, cycle in enumerate(self.cycles):
        #     print(i, cycle)
        
        
    def get_cycles(self, path):
        G = self.create_graph(path)
        cycles = tuple(nx.simple_cycles(G))
        return cycles

    def create_graph(self, path):
        G = nx.DiGraph()
        for i in range(len(path) - 1):
            G.add_edge(path[i], path[i + 1])
        return G

    def get_cyclied_paths(self, paths_with_cycles):
        cyclied_paths = []
        for path, cycles in paths_with_cycles:
            cycle_nodes = tuple((node for cycle in cycles for node in cycle))
            partial_cyclied_paths = map(tuple, filter(bool, split_when(path, lambda n1, n2: (n1 in cycle_nodes) ^ (n2 in cycle_nodes))))
            cyclied_path = tuple(islice(chain(partial_cyclied_paths, repeatfunc(tuple)), 3))
            cyclied_paths.append(cyclied_path)
        return list(set(cyclied_paths))

    def get_normalised_cycles(self, cyclied_paths):
        cyclied_paths = cyclied_paths or self.cyclied_paths
        succesfully_ending = filter(lambda bma: bma[2], cyclied_paths)
        # p = side_effect(lambda bma: print(f'- {bma[0]}\n- {bma[1]}\n- {bma[2]}\n\n'), succesfully_ending)
        cycles = map(lambda bma: bma[1], succesfully_ending)
        normalised = unique_everseen(map(compose(unique_everseen, tuple), cycles))
        return list(normalised)

    def get_nth(self, n: int, of: str, reverse=False):
        self._dataframe.sort_values(by=of, ascending=False)
        if n < 0: 
            n = -n
            reverse = True
        groupped_of = self._dataframe.groupby('Case ID')[of]
        # print(self._dataframe.loc[groupped_of.tail(1).index]['Activity'].value_counts().to_dict())
        activity_indices = (groupped_of.nth(n) if not reverse else groupped_of.tail(n)).index
        if n == 1 and reverse:  # since tail has some problems working
            activity_indices = groupped_of.idxmax()
        activity_df = self._dataframe.loc[activity_indices]
        activities_dict = activity_df['Activity'].value_counts().to_dict()
        return activities_dict

    def filter_any_of_type(self, data: dict[str, list], event_type: str):
        return {activity: descriptions for activity, descriptions in data.items() if any(description['type'] == event_type for description in descriptions)}

    def identify(self, dataframe):
        self.dataframe = dataframe
        curr_data = {}
        for identifier in self.identifiers:
            curr_result_data = identifier.identify(dataframe, curr_data)
            curr_data = merge(curr_data, curr_result_data)
        # print(json.dumps(curr_data, indent=4))
        return curr_data

# %%
class StartEventIdentifier(SingleEventTypeIdentifier): 
    def identify(self, dataframe: pd.DataFrame, earlier_data ):
        partial_data = self.parent.get_nth(0, of='Start Timestamp')
        data = {activity: [{'type': self.name, 'n_occurences': n_occurences}] for activity, n_occurences in partial_data.items()}
        return data
        
class TerminationEventIdentifier(SingleEventTypeIdentifier):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)
        self.not_always_lasts = None
    
    def identify(self, dataframe: pd.DataFrame, earlier_data):
        prelim_end_events = self.parent.get_nth(-1, of='End Timestamp')
        self.init_not_always_lasts(dataframe, prelim_end_events.keys())
        data = {activity: [{'type': 'Termination', 'n_occurences': n_occurences}, {'type': self.get_subevent_name(activity)}] for activity, n_occurences in prelim_end_events.items()}
        return data

    def init_not_always_lasts(self, dataframe: pd.DataFrame, prelim_end_events: list[str]) -> list[str]:
        not_always_lasts = dataframe\
            .groupby('Case ID')['Activity']\
            .apply(lambda group: group[group.isin(prelim_end_events)])\
            .groupby('Case ID')\
            .apply(lambda group: group[:-1])\
            .to_list()
        self.not_always_lasts = list(set(not_always_lasts))

    def get_subevent_name(self, activity):
        return 'Error' if activity in self.not_always_lasts else 'End'


class IntermediateEventIdentifier(SingleEventTypeIdentifier):
     def identify(self, dataframe: pd.DataFrame, earlier_data: dict):
         partial_data = list(dataframe[
            (dataframe['Start Timestamp'] > dataframe.groupby('Case ID')['Start Timestamp'].transform('min')) &
            (dataframe['End Timestamp'] < dataframe.groupby('Case ID')['End Timestamp'].transform('max'))
         ]['Activity'].unique())
         data = {activity: [{'type': self.name}] for activity in partial_data}
         return data

class TimerLoopEventIdentifier(SingleEventTypeIdentifier):
    def identify(self, dataframe: pd.DataFrame, earlier_data: dict):
        std_threshold = 1.2
        pairs_df = get_seq_as_pairs(dataframe)
        same_activity_statistics = ((from_activity, statistics['times'], statistics['mean']) for ((from_activity, to_activity), statistics) in pairs_df.groupby('pairs') if from_activity == to_activity)
        timer_loop_activities = (activity for activity, times, mean in same_activity_statistics if mean != max(times) and np.std(times) > std_threshold)
        data = {activity:[{'type': self.name}] for activity in timer_loop_activities}                
        return data

class TimerExceptionEventIdentifier(SingleEventTypeIdentifier):
    def identify(self, dataframe: pd.DataFrame, earlier_data: dict):
        pairs_df = get_seq_as_pairs(dataframe)
        std_threshold = 1.2

        occurrences = {}
        for group in pairs_df.groupby('pairs'):
            pair = group[0]
            from_activity = pair[0]
            to_activity = pair[1]
            info = [to_activity, group[1]['mean'], group[1]['times']]
            occurrences.setdefault(from_activity, []).append(info)
        
        candidates = [from_activity for from_activity, all_info in occurrences.items() if len(all_info) > 1]        
        candidates_with_times = {from_activity: [time for info in occurrences[from_activity] for time in info[2]] for from_activity in candidates}

        exception_results = []
        for candidate, times in candidates_with_times.items():
            
            longest = float('-inf')
            
            for time_set in times:
                if longest < max(time_set):
                    longest = max(time_set)
            
            for time_set in times:
                mean_time = mean(time_set)
            
                if mean_time == longest or np.std(time_set) < std_threshold:
                    exception_results.append(candidate)
                    
        data = {activity: [{'type': self.name}] for activity in exception_results}
        return data

# %%
eti = EventTypeIdentifier()
eti.identifiers.extend((
    StartEventIdentifier(eti),
    TerminationEventIdentifier(eti),
    IntermediateEventIdentifier(eti),
    TimerLoopEventIdentifier(eti),
    TimerExceptionEventIdentifier(eti),
))
for name, dataframe in dataframes.items():
    print('#'*5, name, '#'*20)
    result = eti.identify(dataframe)
    for activity, activity_result in result.items():
        print(f'{" "*3}{activity}:', activity_result)
# Out:
# ##### repairExample.csv ####################
# Analyze Defect 3
# Inform User 5
# Repair (Complex) 2
# Repair (Simple) 2
# Restart Repair 3
# Test Repair 3
#    Archive Repair: [{'type': 'Termination', 'n_occurences': 890}, {'type': 'End'}]
#    Restart Repair: [{'type': 'Intermediate'}, {'type': 'TimerException'}]
#    Register: [{'type': 'Start', 'n_occurences': 1104}]
#    Test Repair: [{'type': 'Termination', 'n_occurences': 76}, {'type': 'Error'}, {'type': 'Intermediate'}]
#    Inform User: [{'type': 'Termination', 'n_occurences': 136}, {'type': 'Error'}, {'type': 'Intermediate'}, {'type': 'TimerException'}]
#    Repair (Simple): [{'type': 'Intermediate'}]
#    Repair (Complex): [{'type': 'Termination', 'n_occurences': 2}, {'type': 'Error'}, {'type': 'Intermediate'}]
# ##### first_ad.csv ####################
# B 2
#    E: [{'type': 'Intermediate'}]
#    C: [{'type': 'Intermediate'}]
#    A: [{'type': 'Start', 'n_occurences': 13}]
#    B: [{'type': 'Intermediate'}]
#    D: [{'type': 'Termination', 'n_occurences': 13}, {'type': 'End'}]
# ##### second_ad.csv ####################
# B 2
#    E: [{'type': 'Intermediate'}]
#    C: [{'type': 'Intermediate'}]
#    A: [{'type': 'Start', 'n_occurences': 13}]
#    B: [{'type': 'Intermediate'}, {'type': 'TimerException'}]
#    D: [{'type': 'Termination', 'n_occurences': 13}, {'type': 'End'}]

# %% [markdown]
# ### StartEventIdentifier
# Simply identifies event that has no predecessors

# %% [markdown]
# ### TerminationEventIdentifier
# Termination Event detects two tyes of events:
# - End which is the last event that never occurs in before any other event.
# - Error which is an event that appears to be last, but during a normal flow has succesors.
# Both events are marked as Termination Events

# %% [markdown]
# ### IntermediateEventIdentifier
# Is simple an event that is neither a start nor end event

# %% [markdown]
# ### Timer Exception Event Identifier
#
# We use the 'get_seq_as_pairs' function to get the pairs dataframe.
# Then use it by grouping up the pairs and saving all the possible next events after the current selected event with information such as time list of the first event and mean of the time list inside a dictionary. This information can be shown in the following format:
# {First Event : [Second Event, Mean of the time list, Time list (Every time length that first event takes before second event occurs in the whole data)], [Another possible second event,...]}
# Then we check the number of possible second events for the given first event, if the number is bigger than 1, we take them as candidates for this event.
# Since this event type is interruptive, we take the longest time possible for the first event, and if the mean of time equals to this longest time possible for a special second event, we label the first event as Timer Exception Event.
#
# - We also determine a very low standard deviation threshold since a real data can be a little different and not exactly the same time for all of the data, so we check the standard deviation as well.
# - Since in such an event, the first event might take different times for the conditions that interruption does not occur, we do not take into consideration those different times. We are only taking into consideration where the event is interrupted at a given maximum time.

# %% [markdown]
# ### Timer Loop Event Identifier
#
# We use the 'get_seq_as_pairs' function to get the pairs dataframe. We follow a similar but simpler approach compared to Timer Exception Event Identification. While grouping the pairs dataframe by pairs again, we check for if for any given pair first and the second element are the same events. If that is the case, we check with a similar method of Timer Exception Event Identification the maximum time and mean of time since it is an interruptive event as well. Also again, we check for standard deviation for possible small differences in real time examples.

# %% [markdown]
# ### Artificial Data
# The data in first_ad and second_ad is created artificially in order to test the Timer Event identifiers.
# - first_ad: Timer Loop Event identification.
# - second_ad: Timer Exception Event identification.
#
# The data is created manually without using any algorithm, and we tried to simulate reality by adding imperfections such as short delays for interruptive events. And we are detecting this delays and ignoring them by using a threshold with standard deviation in order to make it more realistic and generic.
#
# The differene between the first and the second artificial data is that on the second_ad the second event on the sequence is same as the first one in order to detect the loop, but on the first_ad, the events are different.
#
# Here is an example of creation of the data;
#
# ```
# new_row_list = [ {'Case ID': case,'Activity': 'A', 'Start Timestamp': datetime(2023, 1, day, 9, 0), 'End Timestamp': datetime(2023, 1, day, 9, 30)},
#                  {'Case ID': case,'Activity': 'B', 'Start Timestamp': datetime(2023, 1, day, 9, 30), 'End Timestamp': datetime(2023, 1, day, 10, 16)},
#                  {'Case ID': case,'Activity': 'E', 'Start Timestamp': datetime(2023, 1, day, 10, 16), 'End Timestamp': datetime(2023, 1, day, 10, 30)},
#                  {'Case ID': case,'Activity': 'C', 'Start Timestamp': datetime(2023, 1, day, 10, 30), 'End Timestamp': datetime(2023, 1, day, 11, 0)},
#                  {'Case ID': case,'Activity': 'D', 'Start Timestamp': datetime(2023, 1, day, 11, 45), 'End Timestamp': datetime(2023, 1, day, 12, 15)}
# ]
# ```

# %% [markdown]
# ### Other approachs
# On the last version we are using the get_seq_as_pairs function that is mentioned before in order to detect the loops and cycles. Previously we were trying to use the 'networkx' library to detect these patterns. This library detects the cycles for each case and handles them individually, but also isn't able to detect the cause of the cycle or get the first or last event in the cycle (the event that is a part of the cycle and appears first or last in the given case). This could be detected easily, but the first problem was that there were many exceptions to this in the used data, and second problem was that it is possible to have multiple cycles in a single case.
#
# We were able to surpass these problems with the given functions analyse_cycles and get_cyclied_paths, but we have chosen to move on with a more generic and precise solution using sequences.

# %% [markdown]
# ### get_nth function
# Returns the nth event for any given column for all cases. We use this function for start and end event identifiers using '0' with 'Start Timestamp' and '-1' with 'End Timestamp' for starting, and ending events.
#
# For example, using it with '0'th activity with 'Start Timestamp' column, we get a dictionary that has keys showing first activity when the case is ordered by Start Timestamps with number of occurences as values.
